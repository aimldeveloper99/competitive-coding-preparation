# %% [markdown]
# Valid Anagram
#
#  Given two strings s and t, return true if the two strings are anagrams of each other, otherwise return false.
#
# An anagram is a string that contains the exact same characters as another string, but the order of the characters can be different.
#
# Example 1:
#
# Input: s = "racecar", t = "carrace"
#
# Output: true
# Example 2:
#
# Input: s = "jar", t = "jam"
#
# Output: false
# Constraints:
#
# s and t consist of lowercase English letters.

# %%
from typing import Counter

# %% [markdown]
# The easiet way to solve anagram is to sort the string and then compare it. if equal it is anagram if not false

# %%
def isAnagram(s: str, t: str) -> bool:
    def merge(left, right):
        result = []
        i = j = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                result.append(left[i])
                i += 1
            else:
                result.append(right[j])
                j += 1
        result.extend(left[i:])
        result.extend(right[j:])
        return result
    def merge_sort(chars):
        if len(chars) <= 1:
            return chars
        
        mid = len(chars) // 2
        left = merge_sort(chars[:mid])
        right = merge_sort(chars[mid:])
        return merge(left, right)

    sorted_s = "".join(merge_sort(list(s)))
    sorted_t = "".join(merge_sort(list(t)))

    if sorted_s == sorted_t:
        return True
    else:
        return False

# %%
isAnagram("listen", "silent")
# Out:
# True

# %% [markdown]
# The inbuilt functions are efficient and not suitable to use in interview

# %%
def isAnagram(s: str, t: str) -> bool:   
    #in built function resolve
    #1
    return Counter(s) == Counter(t)

# %%
isAnagram("listen", "silent")
# Out:
# True

# %%
def isAnagram(s: str, t: str) -> bool:   
    #in built function resolve
    #2
    return sorted(s) == sorted(t)

# %%
isAnagram("listen", "silent")
# Out:
# True

# %% [markdown]
# Another best way learned is to create a hash map for each characters along with its repeated count once that is done just compare the keys and value of both count if equal it is true if not false

# %%
def isAnagram(s: str, t: str) -> bool:   

    #solving using the hash 
    if len(s) != len(t):
        return False
    
    count_s, count_t = {}, {}

    for i in range(len(s)):
        count_s[s[i]] = 1 + count_s.get(s[i], 0)
        count_t[t[i]] = 1 + count_t.get(t[i], 0)
    
    for c in count_s:
        if count_s[c] != count_t.get(c, 0):
            return False
    return True

# %%
isAnagram('nre', 'rest')
# Out:
# False
