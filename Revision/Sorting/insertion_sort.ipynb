# %% [markdown]
# Insertion sort
# 1. select the smallest element in the array
# 2. move it to front
# 3. This is like sorting a hand of playing cards
# 4. stable algorithm
# 5. Time complexity => O(n^2)
# 6. space complexity => O(1)

# %%
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr


insertion_sort([5,3,2,1,0,-3,-1,8])
# Out:
# [-3, -1, 0, 1, 2, 3, 5, 8]
